# %% [markdown]
# # Classifing Coral

# %% [markdown]
# ###### By:

# %% [markdown]
# Jared H. Mitchell

# %% [markdown]
# ## Overview

# %% [markdown]
# In twenty 2016, coral bleaching killed 29%-50% of the great barrier reefs coral. Mass bleaching events like this one are unfortunetly becoming more and more common. In order to help the organization The Great Reef Census, I came up with this project idea. The Great Reef Census takes a lot of user subbmitted photos based on surveys of the reef done by volenteers. I thought it could be useful to build a machine learning model that could classify between images of dead, living, and bleahced coral. This could then be used with their allready inplace system to further montiter reef health. Successfully classing all of the photos would provide the organization with a genral idea of the reefs health by using the precentage of living, dead, and bleached coral photos in an area.

# %% [markdown]
# # The Data

# %% [markdown]
# The data that I will be using to build, train, and test our model with is a public data set from [Kaggle](https://www.kaggle.com/sonainjamil/bhd-corals). I started by importing my need packages, and then using ImageDataGenerator from keras to import all of our images while formating them in the process

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255)
training_data = train_datagen.flow_from_directory(
        'Data\Train',
        target_size=(244, 244),
        batch_size=32,
        class_mode='categorical')
testing_data = train_datagen.flow_from_directory(
        'Data\Test',
        target_size=(244, 244),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 1455 images belonging to 3 classes.
# Found 141 images belonging to 3 classes.

# %% [markdown]
# The above cell shows us that our training set has 1,455 images belonging to three different classes, and the testing set is 141 images belonging to 3 different classes. The images are all 244 by 244 pixels and all fall within the class of "living", "bleached", and "dead". Unfortuanlty we do have a large class imblance amung the images. Inside the training set we have 646 images of living coral, 659 images of bleached coral, but only 150 images of dead coral. This is unfortunalty a limitation of this data set. Thankfully, we can use image agmentation to effectivly help increase the number of images in each class. I will be implimenting this in our final model and talk more about the process then. For now, lets move onto my first model. For the sake of time, I implimented some early stopping so I didnt waste time on unneed Epochs. The first model was just your basic Dense Nerual Network. I wanted to get a baseline preformace that I could imporve on when building my final Convelutional Nerual Network.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=7) # Sets up Early Stopping

# %%
model = Sequential([Flatten(),
                    Dense(512, activation = 'relu'),
                    Dense(256, activation = 'relu'),
                    Dropout(rate=0.5),
                    Dense(3, activation = 'softmax')])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
trained_model = model.fit(training_data,
                    validation_data=testing_data,
                    epochs = 30,
                    verbose = 1,
                    callbacks= [early_stopping])
# Out:
# Epoch 1/30
# 46/46 [==============================] - 14s 286ms/step - loss: 25.5249 - accuracy: 0.4763 - val_loss: 1.6586 - val_accuracy: 0.6667
# Epoch 2/30
# 46/46 [==============================] - 13s 282ms/step - loss: 1.4108 - accuracy: 0.5856 - val_loss: 0.7061 - val_accuracy: 0.7092
# Epoch 3/30
# 46/46 [==============================] - 13s 281ms/step - loss: 0.8199 - accuracy: 0.6144 - val_loss: 0.7280 - val_accuracy: 0.6454
# Epoch 4/30
# 46/46 [==============================] - 13s 281ms/step - loss: 0.7930 - accuracy: 0.6213 - val_loss: 0.6901 - val_accuracy: 0.6738
# Epoch 5/30
# 46/46 [==============================] - 13s 281ms/step - loss: 0.8178 - accuracy: 0.6117 - val_loss: 0.7436 - val_accuracy: 0.7163
# Epoch 6/30
# 46/46 [==============================] - 13s 282ms/step - loss: 0.7554 - accuracy: 0.6509 - val_loss: 0.6338 - val_accuracy: 0.7447
# Epoch 7/30
# ...

# %% [markdown]
# Lets plot the Loss and Accuracy over Epochs

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].set_title('Loss')
ax[0].plot(trained_model.epoch, trained_model.history["loss"], label="Train Loss")
ax[0].plot(trained_model.epoch, trained_model.history["val_loss"], label="Validation Loss")
ax[1].set_title('Accuracy')
ax[1].plot(trained_model.epoch, trained_model.history["accuracy"], label="Train Accuracy")
ax[1].plot(trained_model.epoch, trained_model.history["val_accuracy"], label="Validation Accuracy")
ax[0].legend()
ax[1].legend()
print(model.evaluate(testing_data))
# Out:
# 5/5 [==============================] - 0s 63ms/step - loss: 0.6352 - accuracy: 0.7660
# [0.6351621747016907, 0.7659574747085571]

# %%
# cool, lets add image augmentation in and some more layers
# added a seed this time for consistency
train_datagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=90,
    shear_range=0.2,  
    zoom_range=0.2,        
    horizontal_flip=True,
    vertical_flip=True)

training_data = train_datagen.flow_from_directory(
        'Data\Train',
        target_size=(244, 244),
        batch_size=32,
        seed=42,
        class_mode='categorical')
testing_data = train_datagen.flow_from_directory(
        'Data\Test',
        target_size=(244, 244),
        batch_size=32,
        seed=42,
        class_mode='categorical')
# Out:
# Found 1458 images belonging to 3 classes.
# Found 141 images belonging to 3 classes.

# %%
model = Sequential([Conv2D(200, (3,3), activation='LeakyReLU', input_shape=(244, 244, 3)),
                    MaxPool2D(2,2),
                    BatchNormalization(),
                    Conv2D(180, (3,3), activation='LeakyReLU'),
                    MaxPool2D(5,5),
                    Conv2D(128, (2,2), activation='LeakyReLU'),
                    MaxPool2D(3,3),
                    Dropout(rate=0.35),
                    Conv2D(64, (2,3), activation='LeakyReLU'),
                    MaxPool2D(3,3),
                    Flatten(),
                    Dense(250, activation='LeakyReLU'),
                    Dropout(rate=0.5),
                    Dense(180, activation='LeakyReLU'),
                    Dropout(rate=0.35),
                    Dense(128, activation='LeakyReLU'),
                    Dropout(rate=0.2),
                    Dense(3, activation='softmax')])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
trained_model = model.fit(training_data,
                    validation_data=testing_data,
                    epochs=60,
                    verbose=1)
                          #callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3405 - accuracy: 0.8759 - val_loss: 0.2569 - val_accuracy: 0.9362
# Epoch 2/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3355 - accuracy: 0.8807 - val_loss: 0.2737 - val_accuracy: 0.9078
# Epoch 3/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3364 - accuracy: 0.8765 - val_loss: 0.3382 - val_accuracy: 0.8652
# Epoch 4/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3305 - accuracy: 0.8786 - val_loss: 0.3070 - val_accuracy: 0.8936
# Epoch 5/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3446 - accuracy: 0.8800 - val_loss: 0.4066 - val_accuracy: 0.8227
# Epoch 6/60
# 46/46 [==============================] - 199s 4s/step - loss: 0.3527 - accuracy: 0.8697 - val_loss: 0.2933 - val_accuracy: 0.8936
# Epoch 7/60
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].set_title('Loss')
ax[0].plot(trained_model.epoch, trained_model.history["loss"], label="Train Loss")
ax[0].plot(trained_model.epoch, trained_model.history["val_loss"], label="Validation Loss")
ax[1].set_title('Accuracy')
ax[1].plot(trained_model.epoch, trained_model.history["accuracy"], label="Train Accuracy")
ax[1].plot(trained_model.epoch, trained_model.history["val_accuracy"], label="Validation Accuracy")
ax[0].legend()
ax[1].legend()
print(model.evaluate(testing_data))
# Out:
# 5/5 [==============================] - 5s 905ms/step - loss: 0.2586 - accuracy: 0.9149
# [0.2585638463497162, 0.914893627166748]
